# %% [markdown]
# # Convolutional Neural Networks
# ---
# In this notebook, we train a **CNN** to classify images from the CIFAR-10 database.
#
# The images in this database are small color images that fall into one of ten classes; some example images are pictured below.
#
# <img src='notebook_ims/cifar_data.png' width=70% height=70% />

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# Since these are larger (32x32x3) images, it may prove useful to speed up your training time by using a GPU.

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ---
# ## Load the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Downloading may take a minute. We load in the training and test data, split the training data into a training and validation set, then create DataLoaders for each of these sets of data.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
# We'll define a CNN architecture.
# * [Convolutional layers](https://pytorch.org/docs/stable/nn.html#conv2d): 3.
# * [Maxpooling layers](https://pytorch.org/docs/stable/nn.html#maxpool2d).
# * The usual Linear + Dropout layers to avoid overfitting and produce a 10-dim output.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # Convolutional layers
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        
        # Linear layers
        self.fc1 = nn.Linear(4*4*64, 512)
        self.fc2 = nn.Linear(512, 10)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        # Convolutional forward
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        
        # Flattening
        x = x.view(-1, 4*4*64)
        
        # Linear forward
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.log_softmax(self.fc2(x), dim=1)
        
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %% [markdown]
# ### [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.NLLLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ---
# ## Train the Network

# %%
# number of epochs to train the model
n_epochs = 100

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.654527 	Validation Loss: 0.354595
# Validation loss decreased (inf --> 0.354595).  Saving model ...
# Epoch: 2 	Training Loss: 1.301344 	Validation Loss: 0.295228
# Validation loss decreased (0.354595 --> 0.295228).  Saving model ...
# Epoch: 3 	Training Loss: 1.158382 	Validation Loss: 0.275042
# Validation loss decreased (0.295228 --> 0.275042).  Saving model ...
# Epoch: 4 	Training Loss: 1.068274 	Validation Loss: 0.252710
# Validation loss decreased (0.275042 --> 0.252710).  Saving model ...
# Epoch: 5 	Training Loss: 0.991971 	Validation Loss: 0.239118
# Validation loss decreased (0.252710 --> 0.239118).  Saving model ...
# Epoch: 6 	Training Loss: 0.925157 	Validation Loss: 0.220260
# Validation loss decreased (0.239118 --> 0.220260).  Saving model ...
# Epoch: 7 	Training Loss: 0.864908 	Validation Loss: 0.219329
# Validation loss decreased (0.220260 --> 0.219329).  Saving model ...
# Epoch: 8 	Training Loss: 0.820421 	Validation Loss: 0.200029
# Validation loss decreased (0.219329 --> 0.200029).  Saving model ...
# Epoch: 9 	Training Loss: 0.774411 	Validation Loss: 0.195783
# Validation loss decreased (0.200029 --> 0.195783).  Saving model ...
# Epoch: 10 	Training Loss: 0.734160 	Validation Loss: 0.202831
# Epoch: 11 	Training Loss: 0.696748 	Validation Loss: 0.180966
# Validation loss decreased (0.195783 --> 0.180966).  Saving model ...
# Epoch: 12 	Training Loss: 0.661912 	Validation Loss: 0.173845
# Validation loss decreased (0.180966 --> 0.173845).  Saving model ...
# Epoch: 13 	Training Loss: 0.631971 	Validation Loss: 0.170049
# Validation loss decreased (0.173845 --> 0.170049).  Saving model ...
# Epoch: 14 	Training Loss: 0.596348 	Validation Loss: 0.171272
# Epoch: 15 	Training Loss: 0.569999 	Validation Loss: 0.162231
# Validation loss decreased (0.170049 --> 0.162231).  Saving model ...
# Epoch: 16 	Training Loss: 0.539692 	Validation Loss: 0.159927
# Validation loss decreased (0.162231 --> 0.159927).  Saving model ...
# Epoch: 17 	Training Loss: 0.509823 	Validation Loss: 0.159656
# Validation loss decreased (0.159927 --> 0.159656).  Saving model ...
# Epoch: 18 	Training Loss: 0.487450 	Validation Loss: 0.156853
# Validation loss decreased (0.159656 --> 0.156853).  Saving model ...
# Epoch: 19 	Training Loss: 0.461537 	Validation Loss: 0.154794
# Validation loss decreased (0.156853 --> 0.154794).  Saving model ...
# Epoch: 20 	Training Loss: 0.433058 	Validation Loss: 0.155238
# Epoch: 21 	Training Loss: 0.414845 	Validation Loss: 0.154302
# Validation loss decreased (0.154794 --> 0.154302).  Saving model ...
# Epoch: 23 	Training Loss: 0.370711 	Validation Loss: 0.157760
# Epoch: 24 	Training Loss: 0.346318 	Validation Loss: 0.161223
# Epoch: 25 	Training Loss: 0.328542 	Validation Loss: 0.160376
# Epoch: 26 	Training Loss: 0.311990 	Validation Loss: 0.159503
# Epoch: 27 	Training Loss: 0.293424 	Validation Loss: 0.158202
# Epoch: 28 	Training Loss: 0.270913 	Validation Loss: 0.163574
# Epoch: 29 	Training Loss: 0.262953 	Validation Loss: 0.168004
# Epoch: 30 	Training Loss: 0.246458 	Validation Loss: 0.167386
# Epoch: 31 	Training Loss: 0.232906 	Validation Loss: 0.172330
# Epoch: 32 	Training Loss: 0.226092 	Validation Loss: 0.173665
# Epoch: 33 	Training Loss: 0.213315 	Validation Loss: 0.174135
# Epoch: 34 	Training Loss: 0.202727 	Validation Loss: 0.183514
# Epoch: 35 	Training Loss: 0.187964 	Validation Loss: 0.178437
# Epoch: 36 	Training Loss: 0.185762 	Validation Loss: 0.183211
# Epoch: 37 	Training Loss: 0.177607 	Validation Loss: 0.177130
# Epoch: 38 	Training Loss: 0.167924 	Validation Loss: 0.187431
# Epoch: 39 	Training Loss: 0.161218 	Validation Loss: 0.184460
# Epoch: 40 	Training Loss: 0.157532 	Validation Loss: 0.182618
# Epoch: 41 	Training Loss: 0.151870 	Validation Loss: 0.188589
# Epoch: 42 	Training Loss: 0.145100 	Validation Loss: 0.190940
# Epoch: 43 	Training Loss: 0.140920 	Validation Loss: 0.202925
# Epoch: 44 	Training Loss: 0.140057 	Validation Loss: 0.192816
# Epoch: 45 	Training Loss: 0.133670 	Validation Loss: 0.201044
# Epoch: 46 	Training Loss: 0.133824 	Validation Loss: 0.197969
# Epoch: 47 	Training Loss: 0.124995 	Validation Loss: 0.206397
# Epoch: 48 	Training Loss: 0.123247 	Validation Loss: 0.200923
# Epoch: 49 	Training Loss: 0.118596 	Validation Loss: 0.206712
# Epoch: 50 	Training Loss: 0.115533 	Validation Loss: 0.205205
# Epoch: 51 	Training Loss: 0.113159 	Validation Loss: 0.201650
# Epoch: 52 	Training Loss: 0.106507 	Validation Loss: 0.214786
# Epoch: 53 	Training Loss: 0.105127 	Validation Loss: 0.215949
# Epoch: 54 	Training Loss: 0.104563 	Validation Loss: 0.214931
# Epoch: 55 	Training Loss: 0.102978 	Validation Loss: 0.212672
# Epoch: 56 	Training Loss: 0.102377 	Validation Loss: 0.210814
# Epoch: 57 	Training Loss: 0.099652 	Validation Loss: 0.219218
# Epoch: 58 	Training Loss: 0.094503 	Validation Loss: 0.216678
# Epoch: 59 	Training Loss: 0.091144 	Validation Loss: 0.216055
# Epoch: 60 	Training Loss: 0.090004 	Validation Loss: 0.218890
# Epoch: 61 	Training Loss: 0.091733 	Validation Loss: 0.213507
# Epoch: 62 	Training Loss: 0.089548 	Validation Loss: 0.218353
# Epoch: 63 	Training Loss: 0.087762 	Validation Loss: 0.227932
# Epoch: 64 	Training Loss: 0.088480 	Validation Loss: 0.220750
# Epoch: 65 	Training Loss: 0.090561 	Validation Loss: 0.224210
# Epoch: 66 	Training Loss: 0.086922 	Validation Loss: 0.217423
# Epoch: 67 	Training Loss: 0.082662 	Validation Loss: 0.225912
# Epoch: 68 	Training Loss: 0.081362 	Validation Loss: 0.221396
# Epoch: 69 	Training Loss: 0.081784 	Validation Loss: 0.227673
# Epoch: 70 	Training Loss: 0.078455 	Validation Loss: 0.223168
# Epoch: 71 	Training Loss: 0.077783 	Validation Loss: 0.221462
# Epoch: 72 	Training Loss: 0.081368 	Validation Loss: 0.220084
# Epoch: 73 	Training Loss: 0.073286 	Validation Loss: 0.225595
# Epoch: 74 	Training Loss: 0.077358 	Validation Loss: 0.226766
# Epoch: 75 	Training Loss: 0.071656 	Validation Loss: 0.226172
# Epoch: 76 	Training Loss: 0.072269 	Validation Loss: 0.233436
# Epoch: 77 	Training Loss: 0.069370 	Validation Loss: 0.234769
# Epoch: 78 	Training Loss: 0.073691 	Validation Loss: 0.237492
# Epoch: 79 	Training Loss: 0.071804 	Validation Loss: 0.230404
# Epoch: 80 	Training Loss: 0.066948 	Validation Loss: 0.234208
# Epoch: 81 	Training Loss: 0.068627 	Validation Loss: 0.233110
# Epoch: 82 	Training Loss: 0.069048 	Validation Loss: 0.236099
# Epoch: 83 	Training Loss: 0.071356 	Validation Loss: 0.238207
# Epoch: 84 	Training Loss: 0.064003 	Validation Loss: 0.238060
# Epoch: 85 	Training Loss: 0.061831 	Validation Loss: 0.233757
# Epoch: 86 	Training Loss: 0.065356 	Validation Loss: 0.240732
# Epoch: 87 	Training Loss: 0.060937 	Validation Loss: 0.236369
# Epoch: 88 	Training Loss: 0.063382 	Validation Loss: 0.240846
# Epoch: 89 	Training Loss: 0.060585 	Validation Loss: 0.236128
# Epoch: 90 	Training Loss: 0.060892 	Validation Loss: 0.244900
# Epoch: 91 	Training Loss: 0.058318 	Validation Loss: 0.239908
# Epoch: 92 	Training Loss: 0.060120 	Validation Loss: 0.241836
# Epoch: 93 	Training Loss: 0.057214 	Validation Loss: 0.247028
# Epoch: 94 	Training Loss: 0.061225 	Validation Loss: 0.245103
# Epoch: 95 	Training Loss: 0.056994 	Validation Loss: 0.252522
# Epoch: 96 	Training Loss: 0.053754 	Validation Loss: 0.247472
# Epoch: 97 	Training Loss: 0.056146 	Validation Loss: 0.252327
# Epoch: 98 	Training Loss: 0.057927 	Validation Loss: 0.248917
# Epoch: 99 	Training Loss: 0.056579 	Validation Loss: 0.251403
# Epoch: 100 	Training Loss: 0.058737 	Validation Loss: 0.250793

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_cifar.pt'))

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Test the trained model on previously unseen data! A "good" result will be a CNN that gets around 70% (or more) accuracy on these test images.

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.770580
#
# Test Accuracy of airplane: 78% (780/1000)
# Test Accuracy of automobile: 90% (906/1000)
# Test Accuracy of  bird: 65% (654/1000)
# Test Accuracy of   cat: 60% (603/1000)
# Test Accuracy of  deer: 66% (668/1000)
# Test Accuracy of   dog: 60% (606/1000)
# Test Accuracy of  frog: 82% (828/1000)
# Test Accuracy of horse: 75% (753/1000)
# Test Accuracy of  ship: 83% (831/1000)
# Test Accuracy of truck: 78% (783/1000)
#
# Test Accuracy (Overall): 74% (7412/10000)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
